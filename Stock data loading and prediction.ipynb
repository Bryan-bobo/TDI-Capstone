# %%
import pandas as pd
from functools import reduce

# %%
##Apple
df_apple = pd.read_csv("aapl.us.txt", sep=",")
df_apple_1 = df_apple[df_apple['<DATE>']>=20180329].reset_index()
df_apple_2 = df_apple_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_apple_2
# Out:
#         <DATE>    <OPEN>   <CLOSE>    <HIGH>     <LOW>
# 0     20180329   40.0578   40.0519   40.9950   39.8345
# 1     20180402   40.0767   39.7856   40.3280   39.2603
# 2     20180403   40.0179   40.1924   40.2812   39.3599
# 3     20180404   39.3599   40.9620   41.0568   39.3321
# 4     20180405   41.1954   41.2472   41.5861   41.0748
# ...        ...       ...       ...       ...       ...
# 1254  20230323  158.8300  158.9300  161.5501  157.6800
# 1255  20230324  158.8600  160.2500  160.3400  157.8500
# 1256  20230327  159.9400  158.2800  160.7700  157.8700
# 1257  20230328  157.9700  157.6500  158.4900  155.9800
# 1258  20230329  159.3700  160.7700  161.0500  159.3500
#
# [1259 rows x 5 columns]

# %%
##AMAT
df_amat = pd.read_csv("amat.us.txt", sep=",")
df_amat_1 = df_amat[df_amat['<DATE>']>=20180329].reset_index()
df_amat_2 = df_amat_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_amat_2
# Out:
#         <DATE>    <OPEN>   <CLOSE>    <HIGH>     <LOW>
# 0     20180329   51.3135   52.2633   53.2044   50.9292
# 1     20180402   51.9446   49.7084   52.1879   49.2656
# 2     20180403   50.2990   50.7308   51.1635   49.8226
# 3     20180404   49.1455   52.2167   52.4043   49.1455
# 4     20180405   52.5095   51.0246   52.8262   50.6245
# ...        ...       ...       ...       ...       ...
# 1254  20230323  121.2700  122.7800  124.9900  120.1700
# 1255  20230324  121.6400  119.5300  122.1200  118.0500
# 1256  20230327  120.7500  118.8700  120.9800  118.3200
# 1257  20230328  118.8900  116.4000  119.0600  115.5800
# 1258  20230329  118.7200  119.8500  121.0100  117.3600
#
# [1259 rows x 5 columns]

# %%
##AMD
df_amd = pd.read_csv("amd.us.txt", sep=",")
df_amd_1 = df_amd[df_amd['<DATE>']>=20180329].reset_index()
df_amd_2 = df_amd_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_amd_2
# Out:
#         <DATE>  <OPEN>  <CLOSE>  <HIGH>   <LOW>
# 0     20180329    9.94    10.05   10.08   9.810
# 1     20180402    9.99     9.53   10.14   9.510
# 2     20180403    9.63     9.55    9.77   9.300
# 3     20180404    9.08     9.77    9.81   9.040
# 4     20180405   10.05    10.02   10.20   9.910
# ...        ...     ...      ...     ...     ...
# 1254  20230323  100.05   100.28  102.43  98.671
# 1255  20230324   99.18    97.95   99.52  96.740
# 1256  20230327   98.02    96.61   98.93  95.425
# 1257  20230328   96.77    94.56   96.94  92.870
# 1258  20230329   96.07    96.09   96.91  94.870
#
# [1259 rows x 5 columns]

# %%
##ASML
df_asml = pd.read_csv("asml.us.txt", sep=",")
df_asml_1 = df_asml[df_asml['<DATE>']>=20180329].reset_index()
df_asml_2 = df_asml_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_asml_2
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>
# 0     20180329  187.378  189.975  191.757  186.392
# 1     20180402  188.930  184.699  190.523  182.380
# 2     20180403  189.059  190.792  191.438  187.895
# 3     20180404  183.376  189.677  189.727  183.206
# 4     20180405  190.802  190.095  192.235  188.731
# ...        ...      ...      ...      ...      ...
# 1254  20230323  657.740  664.160  673.940  654.940
# 1255  20230324  656.055  647.530  658.950  639.750
# 1256  20230327  655.370  644.050  657.480  643.050
# 1257  20230328  644.100  639.710  644.620  632.380
# 1258  20230329  649.570  659.120  665.170  648.465
#
# [1259 rows x 5 columns]

# %%
##INTEL
df_intc = pd.read_csv("intc.us.txt", sep=",")
df_intc_1 = df_intc[df_intc['<DATE>']>=20180329].reset_index()
df_intc_2 = df_intc_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_intc_2
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>
# 0     20180329  43.7974  45.6396  45.6396  43.7026
# 1     20180402  45.2957  42.8694  45.6025  41.4443
# 2     20180403  42.9406  43.5981  43.7817  42.4239
# 3     20180404  42.1504  43.8071  43.9556  42.0733
# 4     20180405  43.8237  44.1500  44.4469  43.7886
# ...        ...      ...      ...      ...      ...
# 1254  20230323  28.3800  29.0300  29.1600  28.2200
# 1255  20230324  29.0400  29.3600  29.8100  28.9250
# 1256  20230327  29.3700  29.1800  29.7300  29.0800
# 1257  20230328  29.0750  29.2900  29.3300  28.6300
# 1258  20230329  29.7700  31.5200  31.8900  29.7550
#
# [1259 rows x 5 columns]

# %%
##KLA
df_klac = pd.read_csv("klac.us.txt", sep=",")
df_klac_1 = df_klac[df_klac['<DATE>']>=20180329].reset_index()
df_klac_2 = df_klac_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_klac_2
# Out:
#         <DATE>    <OPEN>   <CLOSE>    <HIGH>     <LOW>
# 0     20180329   98.4268   99.8205  101.2080   97.2232
# 1     20180402   99.1682   96.4522   99.4853   95.2465
# 2     20180403   97.4390   98.4951   98.6733   96.3828
# 3     20180404   96.0938  100.0500  100.4340   94.8981
# 4     20180405  101.4650   99.5439  102.1870   99.1088
# ...        ...       ...       ...       ...       ...
# 1254  20230323  388.0600  388.8100  396.9900  381.8700
# 1255  20230324  384.9000  375.0700  385.6300  370.5000
# 1256  20230327  377.5000  374.0200  379.8168  372.3200
# 1257  20230328  373.6000  371.0100  373.8228  365.4250
# 1258  20230329  378.5000  385.1500  388.4800  376.0900
#
# [1259 rows x 5 columns]

# %%
##LAM
df_lrcx = pd.read_csv("lrcx.us.txt", sep=",")
df_lrcx_1 = df_lrcx[df_lrcx['<DATE>']>=20180329].reset_index()
df_lrcx_2 = df_lrcx_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_lrcx_2
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>
# 0     20180329  182.867  187.556  191.562  181.848
# 1     20180402  186.022  178.971  187.289  176.656
# 2     20180403  182.699  182.749  184.222  179.039
# 3     20180404  175.854  186.190  187.090  175.854
# 4     20180405  187.110  180.018  187.773  177.437
# ...        ...      ...      ...      ...      ...
# 1254  20230323  514.390  523.590  532.560  513.330
# 1255  20230324  515.000  502.060  517.410  498.780
# 1256  20230327  508.260  495.770  509.800  494.680
# 1257  20230328  495.400  485.080  496.550  478.770
# 1258  20230329  494.540  515.750  521.155  492.255
#
# [1259 rows x 5 columns]

# %%
##MICRON
df_mu = pd.read_csv("mu.us.txt", sep=",")
df_mu_1 = df_mu[df_mu['<DATE>']>=20180329].reset_index()
df_mu_2 = df_mu_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_mu_2
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>
# 0     20180329  51.7503  51.7304  52.2652  50.7383
# 1     20180402  51.1348  49.6667  51.3140  49.1708
# 2     20180403  50.4008  51.1448  51.3638  49.9247
# 3     20180404  49.2295  52.9693  53.0789  48.8730
# 4     20180405  51.6507  49.4477  51.7891  48.8032
# ...        ...      ...      ...      ...      ...
# 1254  20230323  59.1800  61.3400  61.7800  59.1300
# 1255  20230324  60.5050  61.1600  61.4000  60.5000
# 1256  20230327  61.1900  59.7900  61.4200  59.1701
# 1257  20230328  59.8000  59.2800  59.8700  57.8150
# 1258  20230329  60.9100  63.5400  64.4200  60.8700
#
# [1259 rows x 5 columns]

# %%
##NVIDIA
df_nvda = pd.read_csv("nvda.us.txt", sep=",")
df_nvda_1 = df_nvda[df_nvda['<DATE>']>=20180329].reset_index()
df_nvda_2 = df_nvda_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_nvda_2
# Out:
#         <DATE>    <OPEN>   <CLOSE>    <HIGH>     <LOW>
# 0     20180329   55.4986   57.3482   58.3155   54.6492
# 1     20180402   56.6417   54.7371   58.1055   53.8628
# 2     20180403   56.4089   55.8023   57.0383   54.8111
# 3     20180404   53.2473   56.0222   56.1270   52.9954
# 4     20180405   56.6067   54.8191   56.7346   54.1057
# ...        ...       ...       ...       ...       ...
# 1254  20230323  271.1550  271.9100  274.9900  266.9000
# 1255  20230324  270.3100  267.7900  271.6700  263.5500
# 1256  20230327  268.3700  265.3100  270.0000  263.6500
# 1257  20230328  264.4700  264.1000  265.1300  258.5000
# 1258  20230329  268.2500  269.8400  270.7800  265.9700
#
# [1259 rows x 5 columns]

# %%
##QCOM
df_qcom = pd.read_csv("qcom.us.txt", sep=",")
df_qcom_1 = df_qcom[df_qcom['<DATE>']>=20180329].reset_index()
df_qcom_2 = df_qcom_1[['<DATE>', '<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>']]
df_qcom_2
# Out:
#         <DATE>    <OPEN>   <CLOSE>    <HIGH>     <LOW>
# 0     20180329   48.2607   48.5840   49.0411   47.8949
# 1     20180402   48.3128   47.1824   48.4347   46.5326
# 2     20180403   47.6031   48.0326   48.2694   47.0142
# 3     20180404   47.1735   48.2164   48.3295   46.8403
# 4     20180405   48.6548   48.2607   48.6617   47.7338
# ...        ...       ...       ...       ...       ...
# 1254  20230323  123.9350  124.1500  127.0000  122.1000
# 1255  20230324  123.6300  124.7600  124.9300  122.2500
# 1256  20230327  125.7400  123.6000  126.0600  123.3200
# 1257  20230328  123.6000  121.3400  123.6800  120.2100
# 1258  20230329  123.4200  125.0900  125.9600  123.2500
#
# [1259 rows x 5 columns]

# %%
for df in [df_apple_2, df_amat_2, df_amd_2, df_asml_2, df_intc_2, df_klac_2, df_lrcx_2, df_mu_2, df_nvda_2, df_qcom_2]:
    df.set_index('<DATE>', inplace=True)
    
dfs = [df_apple_2, df_amat_2, df_amd_2, df_asml_2, df_intc_2, df_klac_2, df_lrcx_2, df_mu_2, df_nvda_2, df_qcom_2]
sum_df = pd.DataFrame(columns=dfs[0].columns)
for df in dfs:
    sum_df = sum_df.add(df, fill_value=0)

sum_df.reset_index(inplace=True)
sum_df
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>
# 0     20180329   769.29  783.019  794.068  763.022
# 1     20180402  777.517  753.602   783.41  743.329
# 2     20180403  766.497  771.087  776.001  755.973
# 3     20180404   744.71  779.881  782.013  742.258
# 4     20180405  783.868  768.626   788.44  761.317
# ...        ...      ...      ...      ...      ...
# 1254  20230323  2422.99  2444.98  2485.39  2403.01
# 1255  20230324  2419.12  2385.46  2431.78  2356.89
# 1256  20230327  2404.51  2365.48  2414.99  2356.89
# 1257  20230328  2363.68  2338.42  2367.49  2306.16
# 1258  20230329  2379.12  2426.72  2446.82  2368.23
#
# [1259 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (12, 9)

# %%
_ = sum_df.plot(x="<DATE>", y=['<OPEN>', '<CLOSE>', '<HIGH>', '<LOW>'])

# %%
df_train = sum_df[sum_df['<DATE>']<=20220329]
df_val = sum_df[sum_df['<DATE>'].between(20220330, 20220929, inclusive=False)]
df_test = sum_df[sum_df['<DATE>']>=20220929]

# %%
df_train["Target"] = (df_train["<CLOSE>"] > df_train["<OPEN>"]).shift(periods=-1, fill_value=0).astype(int)
df_val["Target"] = (df_val["<CLOSE>"] > df_val["<OPEN>"]).shift(periods=-1, fill_value=0).astype(int)
df_test["Target"] = (df_test["<CLOSE>"] > df_test["<OPEN>"]).shift(periods=-1, fill_value=0).astype(int)
# Out:
# <ipython-input-16-4bce40da0f5e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Target"] = (df_train["<CLOSE>"] > df_train["<OPEN>"]).shift(periods=-1, fill_value=0).astype(int)
# <ipython-input-16-4bce40da0f5e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Target"] = (df_val["<CLOSE>"] > df_val["<OPEN>"]).shift(periods=-1, fill_value=0).astype(int)
# <ipython-input-16-4bce40da0f5e>:3: SettingWithCopyWarning:
# ...

# %%
df_train
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>  Target
# 0     20180329   769.29  783.019  794.068  763.022       0
# 1     20180402  777.517  753.602   783.41  743.329       1
# 2     20180403  766.497  771.087  776.001  755.973       1
# 3     20180404   744.71  779.881  782.013  742.258       0
# 4     20180405  783.868  768.626   788.44  761.317       0
# ...        ...      ...      ...      ...      ...     ...
# 1003  20220323  2505.63  2470.75  2540.39  2462.03       1
# 1004  20220324  2493.84  2591.59  2594.59  2473.94       0
# 1005  20220325  2583.27  2580.91  2600.45  2531.61       1
# 1006  20220328  2564.02   2608.8  2610.93  2532.86       1
# 1007  20220329   2656.1  2663.26   2681.8  2610.86       0
#
# [1008 rows x 6 columns]

# %%
df_val
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>  Target
# 1009  20220331  2575.26   2517.1  2602.04  2512.05       0
# 1010  20220401  2533.51  2478.77  2545.35  2441.27       1
# 1011  20220404  2489.28  2532.62  2539.32  2477.33       0
# 1012  20220405   2509.4  2404.43  2517.25  2394.43       1
# 1013  20220406  2345.82  2348.58  2391.89  2302.63       1
# ...        ...      ...      ...      ...      ...     ...
# 1129  20220922  1806.65  1769.85  1815.55  1760.63       0
# 1130  20220923  1748.09  1745.65  1758.35  1713.24       0
# 1131  20220926  1744.13  1718.48  1769.68  1714.08       0
# 1132  20220927  1753.22  1738.12  1767.34  1708.98       1
# 1133  20220928  1717.64  1761.86  1771.41  1705.98       0
#
# [125 rows x 6 columns]

# %%
df_test
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>  Target
# 1134  20220929  1723.05  1708.32  1729.69  1679.51       1
# 1135  20220930  1668.42  1672.63  1723.04  1661.34       1
# 1136  20221003  1698.44  1748.41  1770.85  1686.89       1
# 1137  20221004  1820.76   1826.6  1844.43  1800.07       1
# 1138  20221005  1792.07  1835.58     1855  1768.55       0
# ...        ...      ...      ...      ...      ...     ...
# 1254  20230323  2422.99  2444.98  2485.39  2403.01       0
# 1255  20230324  2419.12  2385.46  2431.78  2356.89       0
# 1256  20230327  2404.51  2365.48  2414.99  2356.89       0
# 1257  20230328  2363.68  2338.42  2367.49  2306.16       1
# 1258  20230329  2379.12  2426.72  2446.82  2368.23       0
#
# [125 rows x 6 columns]

# %%
df_train['Target'].value_counts()
# Out:
# 1    522
# 0    486
# Name: Target, dtype: int64

# %%
df_val['Target'].value_counts()
# Out:
# 0    63
# 1    62
# Name: Target, dtype: int64

# %%
df_test['Target'].value_counts()
# Out:
# 1    64
# 0    61
# Name: Target, dtype: int64

# %%
## 3 days rolling average
df_train["Moving_Average_3"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=3, min_periods=1).mean()
df_val["Moving_Average_3"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=3, min_periods=1).mean()
df_test["Moving_Average_3"] = (df_test["<CLOSE>"] - df_test["<OPEN>"]).rolling(window=3, min_periods=1).mean()
# Out:
# <ipython-input-23-16c119f6e5a2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Moving_Average_3"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=3, min_periods=1).mean()
# <ipython-input-23-16c119f6e5a2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Moving_Average_3"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=3, min_periods=1).mean()
# <ipython-input-23-16c119f6e5a2>:4: SettingWithCopyWarning:
# ...

# %%
## 7 days rolling average
df_train["Moving_Average_7"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=7, min_periods=1).mean()
df_val["Moving_Average_7"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=7, min_periods=1).mean()
df_test["Moving_Average_7"] = (df_test["<CLOSE>"] - df_test["<OPEN>"]).rolling(window=7, min_periods=1).mean()
# Out:
# <ipython-input-24-a1c38bcfd010>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Moving_Average_7"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=7, min_periods=1).mean()
# <ipython-input-24-a1c38bcfd010>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Moving_Average_7"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=7, min_periods=1).mean()
# <ipython-input-24-a1c38bcfd010>:4: SettingWithCopyWarning:
# ...

# %%
## 10 days rolling average
df_train["Moving_Average_10"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=10, min_periods=1).mean()
df_val["Moving_Average_10"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=10, min_periods=1).mean()
df_test["Moving_Average_10"] = (df_test["<CLOSE>"] - df_test["<OPEN>"]).rolling(window=10, min_periods=1).mean()
# Out:
# <ipython-input-25-d7231fc1592c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Moving_Average_10"] = (df_train["<CLOSE>"] - df_train["<OPEN>"]).rolling(window=10, min_periods=1).mean()
# <ipython-input-25-d7231fc1592c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Moving_Average_10"] = (df_val["<CLOSE>"] - df_val["<OPEN>"]).rolling(window=10, min_periods=1).mean()
# <ipython-input-25-d7231fc1592c>:4: SettingWithCopyWarning:
# ...

# %%
## Same day direction
df_train["Today_Direction"] = df_train["<CLOSE>"] - df_train["<OPEN>"]
df_val["Today_Direction"] = df_val["<CLOSE>"] - df_val["<OPEN>"]
df_test["Today_Direction"] = df_test["<CLOSE>"] - df_test["<OPEN>"]
# Out:
# <ipython-input-26-3567215ba50a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Today_Direction"] = df_train["<CLOSE>"] - df_train["<OPEN>"]
# <ipython-input-26-3567215ba50a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Today_Direction"] = df_val["<CLOSE>"] - df_val["<OPEN>"]
# <ipython-input-26-3567215ba50a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
## Same day price range
df_train["Price_Range"] = df_train["<HIGH>"] - df_train["<LOW>"]
df_val["Price_Range"] = df_val["<HIGH>"] - df_val["<LOW>"]
df_test["Price_Range"] = df_test["<HIGH>"] - df_test["<LOW>"]
# Out:
# <ipython-input-27-5ddd47678783>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Price_Range"] = df_train["<HIGH>"] - df_train["<LOW>"]
# <ipython-input-27-5ddd47678783>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val["Price_Range"] = df_val["<HIGH>"] - df_val["<LOW>"]
# <ipython-input-27-5ddd47678783>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_train
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW>  Target  Moving_Average_3  \
# 0     20180329   769.29  783.019  794.068  763.022       0         13.728800
# 1     20180402  777.517  753.602   783.41  743.329       1         -5.092950
# 2     20180403  766.497  771.087  776.001  755.973       1         -1.865367
# 3     20180404   744.71  779.881  782.013  742.258       0          5.281967
# 4     20180405  783.868  768.626   788.44  761.317       0          8.173000
# ...        ...      ...      ...      ...      ...     ...               ...
# 1003  20220323  2505.63  2470.75  2540.39  2462.03       1         -2.609567
# 1004  20220324  2493.84  2591.59  2594.59  2473.94       0         27.713533
# 1005  20220325  2583.27  2580.91  2600.45  2531.61       1         20.171033
# 1006  20220328  2564.02   2608.8  2610.93  2532.86       1         46.724767
# 1007  20220329   2656.1  2663.26   2681.8  2610.86       0         16.528067
#
# ...

# %%
# this is the target column that we aim to predict
y_col = "Target"
# these are the input features for the models
X_cols = [
    "<OPEN>",
    "<CLOSE>",
    "<HIGH>",
    "<LOW>",
    "Today_Direction",
    "Price_Range",
    "Moving_Average_3"
]

# %%
X_train = df_train[X_cols]
y_train = df_train[y_col]

X_val = df_val[X_cols]
y_val = df_val[y_col]

X_test = df_val[X_cols]
y_test = df_val[y_col]

# %%
RANDOM_SEED = 42

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import RocCurveDisplay, roc_auc_score
import matplotlib.pyplot as plt

# use default parameters
lr = LogisticRegression()

# fit to train set
lr.fit(X_train, y_train)

# predict probabilities for the validation set
probas = lr.predict_proba(X_val)

# calculate AUC score for the validation set
auc_score = roc_auc_score(y_val, probas[:, 1])

# plot ROC curve and show AUC score
disp = RocCurveDisplay.from_predictions(y_val, probas[:, 1])
disp.plot()
plt.title('ROC curve (AUC = {:.2f})'.format(auc_score))
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay, roc_auc_score
import matplotlib.pyplot as plt

# use default parameters
dt = DecisionTreeClassifier()

# fit to train set
dt.fit(X_train, y_train)

# predict probabilities for the validation set
probas = dt.predict_proba(X_val)

# calculate AUC score for the validation set
auc_score = roc_auc_score(y_val, probas[:, 1])

# plot ROC curve and show AUC score
disp = RocCurveDisplay.from_predictions(y_val, probas[:, 1])
disp.plot()
plt.title('ROC curve (AUC = {:.2f})'.format(auc_score))
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=RANDOM_SEED)
rf.fit(X_train, y_train)

# predict probabilities for the validation set
probas = rf.predict_proba(X_val)

# calculate AUC score for the validation set
auc_score = roc_auc_score(y_val, probas[:, 1])

# plot ROC curve and show AUC score
disp = RocCurveDisplay.from_predictions(y_val, probas[:, 1])
disp.plot()
plt.title('ROC curve (AUC = {:.2f})'.format(auc_score))
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=RANDOM_SEED)
gb.fit(X_train, y_train)

# predict probabilities for the validation set
probas = gb.predict_proba(X_val)

# calculate AUC score for the validation set
auc_score = roc_auc_score(y_val, probas[:, 1])

# plot ROC curve and show AUC score
disp = RocCurveDisplay.from_predictions(y_val, probas[:, 1])
disp.plot()
plt.title('ROC curve (AUC = {:.2f})'.format(auc_score))
plt.show()

# %%
## Warning system for too much price range

# %%
sum_df
sum_df_1 = sum_df

# %%
sum_df_1["Today_Direction"] = sum_df_1["<CLOSE>"] - sum_df_1["<OPEN>"]

# %%
sum_df_1
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction
# 0     20180329   769.29  783.019  794.068  763.022         13.7288
# 1     20180402  777.517  753.602   783.41  743.329        -23.9147
# 2     20180403  766.497  771.087  776.001  755.973          4.5898
# 3     20180404   744.71  779.881  782.013  742.258         35.1708
# 4     20180405  783.868  768.626   788.44  761.317        -15.2416
# ...        ...      ...      ...      ...      ...             ...
# 1254  20230323  2422.99  2444.98  2485.39  2403.01           21.99
# 1255  20230324  2419.12  2385.46  2431.78  2356.89          -33.66
# 1256  20230327  2404.51  2365.48  2414.99  2356.89          -39.03
# 1257  20230328  2363.68  2338.42  2367.49  2306.16         -25.255
# 1258  20230329  2379.12  2426.72  2446.82  2368.23            47.6
#
# [1259 rows x 6 columns]

# %%
Stock_up = sum_df_1[sum_df_1['Today_Direction']>0]
Stock_up
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction
# 0     20180329   769.29  783.019  794.068  763.022         13.7288
# 2     20180403  766.497  771.087  776.001  755.973          4.5898
# 3     20180404   744.71  779.881  782.013  742.258         35.1708
# 7     20180410  775.829   783.18  788.779  767.299          7.3512
# 9     20180412    788.4   796.98  800.997  784.458          8.5793
# ...        ...      ...      ...      ...      ...             ...
# 1248  20230315  2250.66  2265.51  2276.07  2211.16           14.85
# 1249  20230316  2250.85   2373.6  2377.69  2238.85          122.75
# 1251  20230320  2384.13  2395.43  2404.88  2354.37          11.295
# 1254  20230323  2422.99  2444.98  2485.39  2403.01           21.99
# 1258  20230329  2379.12  2426.72  2446.82  2368.23            47.6
#
# [649 rows x 6 columns]

# %%
Stock_down = sum_df_1[sum_df_1['Today_Direction']<0]
Stock_down
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction
# 1     20180402  777.517  753.602   783.41  743.329        -23.9147
# 4     20180405  783.868  768.626   788.44  761.317        -15.2416
# 5     20180406  756.108  746.951  769.995  742.154         -9.1564
# 6     20180409  756.283  754.389  777.106  750.816         -1.8935
# 8     20180411   781.71  781.494   791.03  777.689          -0.216
# ...        ...      ...      ...      ...      ...             ...
# 1252  20230321  2411.77  2383.04  2436.16  2343.78         -28.728
# 1253  20230322  2382.77  2375.75  2463.04  2369.24           -7.02
# 1255  20230324  2419.12  2385.46  2431.78  2356.89          -33.66
# 1256  20230327  2404.51  2365.48  2414.99  2356.89          -39.03
# 1257  20230328  2363.68  2338.42  2367.49  2306.16         -25.255
#
# [610 rows x 6 columns]

# %%
Stock_up['ratio'] = Stock_up['Today_Direction']/Stock_up['<OPEN>']
Stock_up
# Out:
# <ipython-input-42-179ab119ca7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Stock_up['ratio'] = Stock_up['Today_Direction']/Stock_up['<OPEN>']
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction       ratio
# 0     20180329   769.29  783.019  794.068  763.022         13.7288   0.0178461
# 2     20180403  766.497  771.087  776.001  755.973          4.5898  0.00598802
# 3     20180404   744.71  779.881  782.013  742.258         35.1708   0.0472275
# 7     20180410  775.829   783.18  788.779  767.299          7.3512  0.00947529
# 9     20180412    788.4   796.98  800.997  784.458          8.5793   0.0108819
# ...        ...      ...      ...      ...      ...             ...         ...
# ...

# %%
Stock_down['ratio'] = abs(Stock_down['Today_Direction']/Stock_down['<OPEN>'])
Stock_down
# Out:
# <ipython-input-43-c430e320903a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Stock_down['ratio'] = abs(Stock_down['Today_Direction']/Stock_down['<OPEN>'])
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction  \
# 1     20180402  777.517  753.602   783.41  743.329        -23.9147
# 4     20180405  783.868  768.626   788.44  761.317        -15.2416
# 5     20180406  756.108  746.951  769.995  742.154         -9.1564
# 6     20180409  756.283  754.389  777.106  750.816         -1.8935
# 8     20180411   781.71  781.494   791.03  777.689          -0.216
# ...        ...      ...      ...      ...      ...             ...
# 1252  20230321  2411.77  2383.04  2436.16  2343.78         -28.728
# ...

# %%
UP = Stock_up[Stock_up['ratio']>=0.01]
UP
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction      ratio
# 0     20180329   769.29  783.019  794.068  763.022         13.7288  0.0178461
# 3     20180404   744.71  779.881  782.013  742.258         35.1708  0.0472275
# 9     20180412    788.4   796.98  800.997  784.458          8.5793  0.0108819
# 12    20180417   801.66  814.362  817.627  798.255          12.702  0.0158446
# 22    20180501  732.664  747.288  748.498  728.526         14.6238  0.0199598
# ...        ...      ...      ...      ...      ...             ...        ...
# 1243  20230308   2260.6  2302.98  2310.23  2252.19           42.38  0.0187472
# 1246  20230313  2190.07  2219.86  2252.52  2170.51           29.79  0.0136023
# 1247  20230314  2262.66  2293.14  2306.03  2246.63           30.48  0.0134709
# 1249  20230316  2250.85   2373.6  2377.69  2238.85          122.75   0.054535
# 1258  20230329  2379.12  2426.72  2446.82  2368.23            47.6  0.0200074
#
# [336 rows x 7 columns]

# %%
DOWN = Stock_down[Stock_down['ratio']>=0.01]
DOWN
# Out:
#         <DATE>   <OPEN>  <CLOSE>   <HIGH>    <LOW> Today_Direction      ratio
# 1     20180402  777.517  753.602   783.41  743.329        -23.9147  0.0307578
# 4     20180405  783.868  768.626   788.44  761.317        -15.2416  0.0194441
# 5     20180406  756.108  746.951  769.995  742.154         -9.1564  0.0121099
# 10    20180413  803.631   791.13  805.827  786.667        -12.5002  0.0155547
# 14    20180419   781.68  755.118  786.516  750.314        -26.5616  0.0339801
# ...        ...      ...      ...      ...      ...             ...        ...
# 1245  20230310  2279.49  2220.09  2291.93  2202.38           -59.4  0.0260585
# 1252  20230321  2411.77  2383.04  2436.16  2343.78         -28.728  0.0119116
# 1255  20230324  2419.12  2385.46  2431.78  2356.89          -33.66  0.0139142
# 1256  20230327  2404.51  2365.48  2414.99  2356.89          -39.03   0.016232
# 1257  20230328  2363.68  2338.42  2367.49  2306.16         -25.255  0.0106846
#
# [303 rows x 7 columns]

# %%
UP.to_csv('UP.csv')

# %%
DOWN.to_csv('DOWN.csv')
